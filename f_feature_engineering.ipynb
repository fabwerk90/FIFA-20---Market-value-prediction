# %% [markdown]
# # ToDos from previous notebook
#
# #### thoughts for feature engineering
#
# 1. aggregate nationality into continents
# --> DONE
# 2. convert all positions into some sort of "the more positions able to play the more flexible the player is"
# 3. Build average position values for attack, midfield and defending out of individual position values
# 3. investigate what work rate, international reputation and skill_moves refer to
# 4. investigate upon player traits and aggregate into broader categories

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_fp = pd.read_csv("data/fp_data_v2.csv", index_col=0)
df_gk = pd.read_csv("data/gk_data_v2.csv", index_col=0)
pd.set_option('display.max_columns', None)

# %%
df_gk.head(3)
# Out:
#    market_value_€            player_name              long_name  \
# 0      80000000.0              Jan Oblak              Jan Oblak
# 1      72000000.0  Marc-André ter Stegen  Marc-André ter Stegen
# 2      72000000.0                Alisson  Alisson Ramses Becker
#
#    year_of_birth  player_age  height_cm  weight_kg nationality main_position  \
# 0           1993          26        188         87    Slovenia       Torwart
# 1           1992          28        187         85     Germany       Torwart
# 2           1992          28        191         91      Brazil       Torwart
#
#               club          league  divison  national_team_current_or_past  \
# 0  Atlético Madrid          LaLiga        1                              1
# 1     FC Barcelona          LaLiga        1                              1
# 2     FC Liverpool  Premier League        1                              1
#
#   national_team_country  current_national_player  no_current_national_player  \
# 0             Slowenien                        1                           0
# 1           Deutschland                        1                           0
# 2             Brasilien                        0                           1
#
#    national_team_appearances  international_reputation  overall  potential  \
# 0                         28                         3       91         93
# 1                         24                         3       90         93
# 2                         44                         3       89         91
#
#   preferred_foot  weak_foot  skill_moves  gk_diving  gk_handling  gk_kicking  \
# 0          Right          3            1         87           92          78
# 1          Right          4            1         88           85          88
# 2          Right          3            1         85           84          85
#
#    gk_reflexes  gk_speed  gk_positioning  \
# 0           89        52              90
# 1           90        45              88
# 2           89        51              90
#
#                                     player_traits  attacking_short_passing  \
# 0                      Flair, Acrobatic Clearance                       43
# 1  Swerve Pass, Acrobatic Clearance, Flair Passes                       61
# 2                              Flair, Swerve Pass                       45
#
#    skill_long_passing  skill_ball_control  movement_acceleration  \
# 0                  40                  30                     43
# 1                  63                  30                     38
# 2                  44                  30                     56
#
#    movement_sprint_speed  movement_agility  movement_reactions  \
# 0                     60                67                  88
# 1                     50                37                  86
# 2                     47                40                  88
#
#    movement_balance  power_shot_power  power_jumping  power_stamina  \
# 0                49                59             78             41
# 1                43                66             79             35
# 2                37                64             52             32
#
#    power_strength  mentality_aggression  mentality_vision  \
# 0              78                    34                65
# 1              78                    43                70
# 2              78                    27                66
#
#    mentality_composure  goalkeeping_diving  goalkeeping_handling  \
# 0                   68                  87                    92
# 1                   70                  88                    85
# 2                   65                  85                    84
#
#    goalkeeping_kicking  goalkeeping_positioning  goalkeeping_reflexes
# 0                   78                       90                    89
# 1                   88                       88                    90
# 2                   85                       90                    89

# %%
df_fp.head(3)
# Out:
#    market_value_€        player_name                            long_name  \
# 0     112000000.0       Lionel Messi       Lionel Andrés Messi Cuccittini
# 1      60000000.0  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro
# 2     128000000.0             Neymar        Neymar da Silva Santos Junior
#
#    year_of_birth  player_age  height_cm  weight_kg nationality main_position  \
# 0           1987          32        170         72   Argentina   Rechtsaußen
# 1           1985          35        187         83    Portugal    Linksaußen
# 2           1992          28        175         68      Brazil    Linksaußen
#
#   all_positions                    club   league  divison  \
# 0    RW, CF, ST            FC Barcelona   LaLiga        1
# 1        ST, LW          Juventus Turin  Serie A        1
# 2       LW, CAM  FC Paris Saint-Germain  Ligue 1        1
#
#    national_team_current_or_past national_team_country  \
# 0                              1           Argentinien
# 1                              1              Portugal
# 2                              1             Brasilien
#
#    current_national_player  no_current_national_player  \
# 0                        1                           0
# 1                        1                           0
# 2                        1                           0
#
#    national_team_appearances  international_reputation  overall  potential  \
# 0                        138                         5       94         94
# 1                        164                         5       93         93
# 2                        102                         5       92         92
#
#   preferred_foot  weak_foot  skill_moves    work_rate  pace  shooting  \
# 0           Left          4            4   Medium/Low    87        92
# 1          Right          4            5     High/Low    90        93
# 2          Right          5            5  High/Medium    91        85
#
#    passing  dribbling  defending  physic  \
# 0       92         96         39      66
# 1       82         89         35      78
# 2       87         95         32      58
#
#                                        player_traits  attacking_crossing  \
# 0  Beat Offside Trap, Argues with Officials, Earl...                  88
# 1  Long Throw-in, Selfish, Argues with Officials,...                  84
# 2  Power Free-Kick, Injury Free, Selfish, Early C...                  87
#
#    attacking_finishing  attacking_heading_accuracy  attacking_short_passing  \
# 0                   95                          70                       92
# 1                   94                          89                       83
# 2                   87                          62                       87
#
#    attacking_volleys  skill_dribbling  skill_curve  skill_fk_accuracy  \
# 0                 88               97           93                 94
# 1                 87               89           81                 76
# 2                 87               96           88                 87
#
#    skill_long_passing  skill_ball_control  movement_acceleration  \
# 0                  92                  96                     91
# 1                  77                  92                     89
# 2                  81                  95                     94
#
#    movement_sprint_speed  movement_agility  movement_reactions  \
# 0                     84                93                  95
# 1                     91                87                  96
# 2                     89                96                  92
#
#    movement_balance  power_shot_power  power_jumping  power_stamina  \
# 0                95                86             68             75
# 1                71                95             95             85
# 2                84                80             61             81
#
#    power_strength  power_long_shots  mentality_aggression  \
# 0              68                94                    48
# 1              78                93                    63
# 2              49                84                    51
#
#    mentality_interceptions  mentality_positioning  mentality_vision  \
# 0                       40                     94                94
# 1                       29                     95                82
# 2                       36                     87                90
#
#    mentality_penalties  mentality_composure  defending_marking  \
# 0                   75                   96                 33
# 1                   85                   95                 28
# 2                   90                   94                 27
#
#    defending_standing_tackle  defending_sliding_tackle  ls  st  rs  lw  lf  \
# 0                         37                        26  89  89  89  93  93
# 1                         32                        24  91  91  91  89  90
# 2                         26                        29  84  84  84  90  89
#
#    cf  rf  rw  lam  cam  ram  lm  lcm  cm  rcm  rm  lwb  ldm  cdm  rdm  rwb  \
# 0  93  93  93   93   93   93  92   87  87   87  92   68   66   66   66   68
# 1  90  90  89   88   88   88  88   81  81   81  88   65   61   61   61   65
# 2  89  89  90   90   90   90  89   82  82   82  89   66   61   61   61   66
#
#    lb  lcb  cb  rcb  rb
# 0  63   52  52   52  63
# 1  61   53  53   53  61
# 2  61   46  46   46  61

# %% [markdown]
# ## 1 - Nationality and continent

# %%
# 1. Nationality and National team country
translations = pd.read_csv("data/countries_translations_ger_eng.csv")
translations_dict = pd.Series(translations.tm_english.values,index=translations.tm_deutsch).to_dict()
translations_dict
# Out:
# {'Algerien': 'Algeria',
#  'Angola': 'Angola',
#  'Benin': 'Benin',
#  'Burkina Faso': 'Burkina Faso',
#  'Burundi': 'Burundi',
#  'Kamerun': 'Cameroon',
#  'Kap Verde': 'Cape Verde',
#  'Komoren': 'Comoros',
#  'Ägypten': 'Egypt',
#  'Eritrea': 'Eritrea',
#  'Gabun': 'Gabon',
#  'Ghana': 'Ghana',
#  'Guinea': 'Guinea',
#  'Kenia': 'Kenya',
#  'Liberia': 'Liberia',
#  'Libyen': 'Libya',
#  'Madagaskar': 'Madagascar',
#  'Malawi': 'Malawi',
#  'Mali': 'Mali',
#  'Mauretanien': 'Mauritania',
#  'Marokko': 'Morocco',
#  'Mosambik': 'Mozambique',
#  'Namibia': 'Namibia',
#  'Niger': 'Niger',
#  'Nigeria': 'Nigeria',
#  'Ruanda': 'Rwanda',
#  'Senegal': 'Senegal',
#  'Sierra Leone': 'Sierra Leone',
#  'Südafrika': 'South Africa',
#  'Südsudan': 'South Sudan',
#  'Togo': 'Togo',
#  'Tunesien': 'Tunisia',
#  'Uganda': 'Uganda',
#  'Sambia': 'Zambia',
#  'Simbabwe': 'Zimbabwe',
#  'Äquatorialguinea': 'Equatorial Guinea',
#  'Afghanistan': 'Afghanistan',
#  'Armenien': 'Armenia',
#  'Aserbaidschan': 'Azerbaijan',
#  'Bahrain': 'Bahrain',
#  'China': 'China PR',
#  'Georgien': 'Georgia',
#  'Indien': 'India',
#  'Indonesien': 'Indonesia',
#  'Iran': 'Iran',
#  'Irak': 'Iraq',
#  'Israel': 'Israel',
#  'Japan': 'Japan',
#  'Kasachstan': 'Kazakhstan',
#  'Libanon': 'Lebanon',
#  'Palästina': 'Palestine',
#  'Philippinen': 'Philippines',
#  'Russland': 'Russia',
#  'Saudi-Arabien': 'Saudi Arabia',
#  'Syrien': 'Syria',
#  'Thailand': 'Thailand',
#  'Türkei': 'Turkey',
#  'Usbekistan': 'Uzbekistan',
#  'Zypern': 'Cyprus',
#  'Albanien': 'Albania',
#  'Österreich': 'Austria',
#  'Belgien': 'Belgium',
#  'Bosnien-Herzegowina': 'Bosnia Herzegovina',
#  'Bulgarien': 'Bulgaria',
#  'Kroatien': 'Croatia',
#  'Tschechien': 'Czech Republic',
#  'Dänemark': 'Denmark',
#  'Estland': 'Estonia',
#  'Finnland': 'Finland',
#  'Frankreich': 'France',
#  'Deutschland': 'Germany',
#  'Griechenland': 'Greece',
#  'Ungarn': 'Hungary',
#  'Irland': 'Republic of Ireland',
#  'Italien': 'Italy',
#  'Kosovo': 'Kosovo',
#  'Liechtenstein': 'Liechtenstein',
#  'Litauen': 'Lithuania',
#  'Lettland': 'Latvia',
#  'Luxemburg': 'Luxembourg',
#  'Moldawien': 'Moldova',
#  'Montenegro': 'Montenegro',
#  'Niederlande': 'Netherlands',
#  'Norwegen': 'Norway',
#  'Polen': 'Poland',
#  'Portugal': 'Portugal',
#  'Rumänien': 'Romania',
#  'Serbien': 'Serbia',
#  'Slowakei': 'Slovakia',
#  'Slowenien': 'Slovenia',
#  'Spanien': 'Spain',
#  'Schweden': 'Sweden',
#  'Schweiz': 'Switzerland',
#  'Ukraine': 'Ukraine',
#  'Antigua und Barbuda': 'Antigua & Barbuda',
#  'Aruba': 'Aruba',
#  'Belize': 'Belize',
#  'Bermuda': 'Bermuda',
#  'Kanada': 'Canada',
#  'Costa Rica': 'Costa Rica',
#  'Kuba': 'Cuba',
#  'Dominikanische Republik': 'Dominican Republic',
#  'El Salvador': 'El Salvador',
#  'Grenada': 'Grenada',
#  'Guadeloupe': 'Guadeloupe',
#  'Haiti': 'Haiti',
#  'Honduras': 'Honduras',
#  'Jamaika': 'Jamaica',
#  'Martinique': 'Martinique',
#  'Mexiko': 'Mexico',
#  'Montserrat': 'Montserrat',
#  'Panama': 'Panama',
#  'Puerto Rico': 'Puerto Rico',
#  'Australien': 'Australia',
#  'Neuseeland': 'New Zealand',
#  'Samoa': 'Samoa',
#  'Argentinien': 'Argentina',
#  'Bolivien': 'Bolivia',
#  'Brasilien': 'Brazil',
#  'Chile': 'Chile',
#  'Kolumbien': 'Colombia',
#  'Ecuador': 'Ecuador',
#  'Guyana': 'Guyana',
#  'Paraguay': 'Paraguay',
#  'Peru': 'Peru',
#  'Uruguay': 'Uruguay',
#  'Venezuela': 'Venezuela',
#  'Curaçao': 'Curacao',
#  'Demokratische Republik Kongo': 'DR Congo',
#  'England': 'England',
#  'Färöer': 'Faroe Islands',
#  'Französisch-Guayana': 'French-Guayana',
#  'Gambia': 'Gambia',
#  'Guinea-Bissau': 'Guinea Bissau',
#  'Hongkong': 'Hong Kong',
#  'Island': 'Iceland',
#  'Elfenbeinküste': 'Ivory Coast',
#  'Nordkorea': 'Korea DPR',
#  'Südkorea': 'Korea Republic',
#  'Neukaledonien': 'New Caledonia',
#  'No national player': 'No national player',
#  'Nordirland': 'Northern Ireland',
#  'São Tomé und Príncipe': 'São Tomé & Príncipe',
#  'Schottland': 'Scotland',
#  'St. Kitts und Nevis': 'St Kitts Nevis',
#  'Chinesisch Taipeh (Taiwan)': 'Chinese Taipei',
#  'Tschad': 'Chad',
#  'Trinidad und Tobago': 'Trinidad & Tobago',
#  'Vereinigte Staaten': 'United States',
#  'Wales': 'Wales',
#  'Nordmazedonien': 'FYR Macedonia',
#  'Republik Kongo': 'Congo',
#  'Zentralafrikanische Republik': 'Central African Rep.'}

# %%
df_fp["national_team_country"] = df_fp["national_team_country"].replace(translations_dict)
df_gk["national_team_country"] = df_gk["national_team_country"].replace(translations_dict)

df_fp.head(3)
# Out:
#    market_value_€        player_name                            long_name  \
# 0     112000000.0       Lionel Messi       Lionel Andrés Messi Cuccittini
# 1      60000000.0  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro
# 2     128000000.0             Neymar        Neymar da Silva Santos Junior
#
#    year_of_birth  player_age  height_cm  weight_kg nationality main_position  \
# 0           1987          32        170         72   Argentina   Rechtsaußen
# 1           1985          35        187         83    Portugal    Linksaußen
# 2           1992          28        175         68      Brazil    Linksaußen
#
#   all_positions                    club   league  divison  \
# 0    RW, CF, ST            FC Barcelona   LaLiga        1
# 1        ST, LW          Juventus Turin  Serie A        1
# 2       LW, CAM  FC Paris Saint-Germain  Ligue 1        1
#
#    national_team_current_or_past national_team_country  \
# 0                              1             Argentina
# 1                              1              Portugal
# 2                              1                Brazil
#
#    current_national_player  no_current_national_player  \
# 0                        1                           0
# 1                        1                           0
# 2                        1                           0
#
#    national_team_appearances  international_reputation  overall  potential  \
# 0                        138                         5       94         94
# 1                        164                         5       93         93
# 2                        102                         5       92         92
#
#   preferred_foot  weak_foot  skill_moves    work_rate  pace  shooting  \
# 0           Left          4            4   Medium/Low    87        92
# 1          Right          4            5     High/Low    90        93
# 2          Right          5            5  High/Medium    91        85
#
#    passing  dribbling  defending  physic  \
# 0       92         96         39      66
# 1       82         89         35      78
# 2       87         95         32      58
#
#                                        player_traits  attacking_crossing  \
# 0  Beat Offside Trap, Argues with Officials, Earl...                  88
# 1  Long Throw-in, Selfish, Argues with Officials,...                  84
# 2  Power Free-Kick, Injury Free, Selfish, Early C...                  87
#
#    attacking_finishing  attacking_heading_accuracy  attacking_short_passing  \
# 0                   95                          70                       92
# 1                   94                          89                       83
# 2                   87                          62                       87
#
#    attacking_volleys  skill_dribbling  skill_curve  skill_fk_accuracy  \
# 0                 88               97           93                 94
# 1                 87               89           81                 76
# 2                 87               96           88                 87
#
#    skill_long_passing  skill_ball_control  movement_acceleration  \
# 0                  92                  96                     91
# 1                  77                  92                     89
# 2                  81                  95                     94
#
#    movement_sprint_speed  movement_agility  movement_reactions  \
# 0                     84                93                  95
# 1                     91                87                  96
# 2                     89                96                  92
#
#    movement_balance  power_shot_power  power_jumping  power_stamina  \
# 0                95                86             68             75
# 1                71                95             95             85
# 2                84                80             61             81
#
#    power_strength  power_long_shots  mentality_aggression  \
# 0              68                94                    48
# 1              78                93                    63
# 2              49                84                    51
#
#    mentality_interceptions  mentality_positioning  mentality_vision  \
# 0                       40                     94                94
# 1                       29                     95                82
# 2                       36                     87                90
#
#    mentality_penalties  mentality_composure  defending_marking  \
# 0                   75                   96                 33
# 1                   85                   95                 28
# 2                   90                   94                 27
#
#    defending_standing_tackle  defending_sliding_tackle  ls  st  rs  lw  lf  \
# 0                         37                        26  89  89  89  93  93
# 1                         32                        24  91  91  91  89  90
# 2                         26                        29  84  84  84  90  89
#
#    cf  rf  rw  lam  cam  ram  lm  lcm  cm  rcm  rm  lwb  ldm  cdm  rdm  rwb  \
# 0  93  93  93   93   93   93  92   87  87   87  92   68   66   66   66   68
# 1  90  90  89   88   88   88  88   81  81   81  88   65   61   61   61   65
# 2  89  89  90   90   90   90  89   82  82   82  89   66   61   61   61   66
#
#    lb  lcb  cb  rcb  rb
# 0  63   52  52   52  63
# 1  61   53  53   53  61
# 2  61   46  46   46  61

# %%
country_continents1 = pd.read_csv("data/countries_continent.csv")
country_continents1 = country_continents1.rename(columns={"country": "nationality"})

df_fp = pd.merge(df_fp,country_continents1,on='nationality')
df_gk = pd.merge(df_gk,country_continents1,on='nationality')

df_fp.head(3)
# Out:
#    market_value_€    player_name                          long_name  \
# 0     112000000.0   Lionel Messi     Lionel Andrés Messi Cuccittini
# 1      52000000.0  Sergio Agüero  Sergio Leonel Agüero del Castillo
# 2      72000000.0   Paulo Dybala        Paulo Bruno Exequiel Dybala
#
#    year_of_birth  player_age  height_cm  weight_kg nationality  \
# 0           1987          32        170         72   Argentina
# 1           1988          32        173         70   Argentina
# 2           1993          26        177         75   Argentina
#
#      main_position all_positions             club          league  divison  \
# 0      Rechtsaußen    RW, CF, ST     FC Barcelona          LaLiga        1
# 1    Mittelstürmer            ST  Manchester City  Premier League        1
# 2  Hängende Spitze       CAM, RW   Juventus Turin         Serie A        1
#
#    national_team_current_or_past national_team_country  \
# 0                              1             Argentina
# 1                              1             Argentina
# 2                              1             Argentina
#
#    current_national_player  no_current_national_player  \
# 0                        1                           0
# 1                        1                           0
# 2                        1                           0
#
#    national_team_appearances  international_reputation  overall  potential  \
# 0                        138                         5       94         94
# 1                         97                         4       89         89
# 2                         29                         3       88         92
#
#   preferred_foot  weak_foot  skill_moves      work_rate  pace  shooting  \
# 0           Left          4            4     Medium/Low    87        92
# 1          Right          4            4    High/Medium    80        90
# 2           Left          3            4  Medium/Medium    83        82
#
#    passing  dribbling  defending  physic  \
# 0       92         96         39      66
# 1       77         88         33      74
# 2       84         90         43      64
#
#                                        player_traits  attacking_crossing  \
# 0  Beat Offside Trap, Argues with Officials, Earl...                  88
# 1        Avoids Using Weaker Foot, Outside Foot Shot                  70
# 2  Beat Offside Trap, Selfish, Finesse Shot, Spee...                  82
#
#    attacking_finishing  attacking_heading_accuracy  attacking_short_passing  \
# 0                   95                          70                       92
# 1                   93                          78                       83
# 2                   80                          64                       87
#
#    attacking_volleys  skill_dribbling  skill_curve  skill_fk_accuracy  \
# 0                 88               97           93                 94
# 1                 85               88           83                 73
# 2                 88               90           88                 88
#
#    skill_long_passing  skill_ball_control  movement_acceleration  \
# 0                  92                  96                     91
# 1                  64                  89                     82
# 2                  75                  93                     86
#
#    movement_sprint_speed  movement_agility  movement_reactions  \
# 0                     84                93                  95
# 1                     78                84                  92
# 2                     81                91                  84
#
#    movement_balance  power_shot_power  power_jumping  power_stamina  \
# 0                95                86             68             75
# 1                91                89             81             79
# 2                85                80             75             79
#
#    power_strength  power_long_shots  mentality_aggression  \
# 0              68                94                    48
# 1              74                84                    65
# 2              61                86                    48
#
#    mentality_interceptions  mentality_positioning  mentality_vision  \
# 0                       40                     94                94
# 1                       24                     93                83
# 2                       42                     80                87
#
#    mentality_penalties  mentality_composure  defending_marking  \
# 0                   75                   96                 33
# 1                   83                   90                 30
# 2                   86                   84                 32
#
#    defending_standing_tackle  defending_sliding_tackle  ls  st  rs  lw  lf  \
# 0                         37                        26  89  89  89  93  93
# 1                         29                        24  87  87  87  85  87
# 2                         48                        40  80  80  80  85  85
#
#    cf  rf  rw  lam  cam  ram  lm  lcm  cm  rcm  rm  lwb  ldm  cdm  rdm  rwb  \
# 0  93  93  93   93   93   93  92   87  87   87  92   68   66   66   66   68
# 1  87  87  85   85   85   85  83   77  77   77  83   60   58   58   58   60
# 2  85  85  85   86   86   86  85   80  80   80  85   68   64   64   64   68
#
#    lb  lcb  cb  rcb  rb geographical_continent
# 0  63   52  52   52  63          South America
# 1  56   50  50   50  56          South America
# 2  64   54  54   54  64          South America

# %%
def movecol(df, cols_to_move=[], ref_col='', place='After'):
    
    cols = df.columns.tolist()    
    if place == 'After':
        seg1 = cols[:list(cols).index(ref_col) + 1]
        seg2 = cols_to_move
    if place == 'Before':
        seg1 = cols[:list(cols).index(ref_col)]
        seg2 = cols_to_move + [ref_col]
    
    seg1 = [i for i in seg1 if i not in seg2]
    seg3 = [i for i in cols if i not in seg1 + seg2]
    
    return(df[seg1 + seg2 + seg3])

df_fp = movecol(df_fp, cols_to_move=["geographical_continent"], ref_col="nationality", place="After")
df_gk = movecol(df_gk, cols_to_move=["geographical_continent"], ref_col="nationality", place="After")

df_fp = df_fp.sort_values(by='overall', ascending=False)
df_gk = df_gk.sort_values(by='overall', ascending=False)
df_fp = df_fp.reset_index(drop=True)
df_gk = df_gk.reset_index(drop=True)

df_fp.head(3)
# Out:
#    market_value_€        player_name                            long_name  \
# 0     112000000.0       Lionel Messi       Lionel Andrés Messi Cuccittini
# 1      60000000.0  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro
# 2     128000000.0             Neymar        Neymar da Silva Santos Junior
#
#    year_of_birth  player_age  height_cm  weight_kg nationality  \
# 0           1987          32        170         72   Argentina
# 1           1985          35        187         83    Portugal
# 2           1992          28        175         68      Brazil
#
#   geographical_continent main_position all_positions                    club  \
# 0          South America   Rechtsaußen    RW, CF, ST            FC Barcelona
# 1                 Europe    Linksaußen        ST, LW          Juventus Turin
# 2          South America    Linksaußen       LW, CAM  FC Paris Saint-Germain
#
#     league  divison  national_team_current_or_past national_team_country  \
# 0   LaLiga        1                              1             Argentina
# 1  Serie A        1                              1              Portugal
# 2  Ligue 1        1                              1                Brazil
#
#    current_national_player  no_current_national_player  \
# 0                        1                           0
# 1                        1                           0
# 2                        1                           0
#
#    national_team_appearances  international_reputation  overall  potential  \
# 0                        138                         5       94         94
# 1                        164                         5       93         93
# 2                        102                         5       92         92
#
#   preferred_foot  weak_foot  skill_moves    work_rate  pace  shooting  \
# 0           Left          4            4   Medium/Low    87        92
# 1          Right          4            5     High/Low    90        93
# 2          Right          5            5  High/Medium    91        85
#
#    passing  dribbling  defending  physic  \
# 0       92         96         39      66
# 1       82         89         35      78
# 2       87         95         32      58
#
#                                        player_traits  attacking_crossing  \
# 0  Beat Offside Trap, Argues with Officials, Earl...                  88
# 1  Long Throw-in, Selfish, Argues with Officials,...                  84
# 2  Power Free-Kick, Injury Free, Selfish, Early C...                  87
#
#    attacking_finishing  attacking_heading_accuracy  attacking_short_passing  \
# 0                   95                          70                       92
# 1                   94                          89                       83
# 2                   87                          62                       87
#
#    attacking_volleys  skill_dribbling  skill_curve  skill_fk_accuracy  \
# 0                 88               97           93                 94
# 1                 87               89           81                 76
# 2                 87               96           88                 87
#
#    skill_long_passing  skill_ball_control  movement_acceleration  \
# 0                  92                  96                     91
# 1                  77                  92                     89
# 2                  81                  95                     94
#
#    movement_sprint_speed  movement_agility  movement_reactions  \
# 0                     84                93                  95
# 1                     91                87                  96
# 2                     89                96                  92
#
#    movement_balance  power_shot_power  power_jumping  power_stamina  \
# 0                95                86             68             75
# 1                71                95             95             85
# 2                84                80             61             81
#
#    power_strength  power_long_shots  mentality_aggression  \
# 0              68                94                    48
# 1              78                93                    63
# 2              49                84                    51
#
#    mentality_interceptions  mentality_positioning  mentality_vision  \
# 0                       40                     94                94
# 1                       29                     95                82
# 2                       36                     87                90
#
#    mentality_penalties  mentality_composure  defending_marking  \
# 0                   75                   96                 33
# 1                   85                   95                 28
# 2                   90                   94                 27
#
#    defending_standing_tackle  defending_sliding_tackle  ls  st  rs  lw  lf  \
# 0                         37                        26  89  89  89  93  93
# 1                         32                        24  91  91  91  89  90
# 2                         26                        29  84  84  84  90  89
#
#    cf  rf  rw  lam  cam  ram  lm  lcm  cm  rcm  rm  lwb  ldm  cdm  rdm  rwb  \
# 0  93  93  93   93   93   93  92   87  87   87  92   68   66   66   66   68
# 1  90  90  89   88   88   88  88   81  81   81  88   65   61   61   61   65
# 2  89  89  90   90   90   90  89   82  82   82  89   66   61   61   61   66
#
#    lb  lcb  cb  rcb  rb
# 0  63   52  52   52  63
# 1  61   53  53   53  61
# 2  61   46  46   46  61

# %% [markdown]
# ## 2 - Positions
#
# only applies for fieldplayers, since goalkeepers only have one position

# %%
df_fp["main_position"].value_counts()
# Out:
# Innenverteidiger         2176
# Mittelstürmer            1565
# Zentrales Mittelfeld     1392
# Defensives Mittelfeld    1067
# Rechter Verteidiger       992
# Linker Verteidiger        953
# Linksaußen                744
# Offensives Mittelfeld     744
# Rechtsaußen               719
# Linkes Mittelfeld         243
# Rechtes Mittelfeld        208
# Hängende Spitze           109
# Mittelfeld                 35
# Sturm                      19
# Abwehr                     13
# Name: main_position, dtype: int64

# %%
# adjust german positions to english/fifa notation
positions_tm_in_fifa = pd.read_csv("data/tm_mainpos_to_fifa_pos.csv")
positions_tm_in_fifa_dict = pd.Series(positions_tm_in_fifa.fifa.values,index=positions_tm_in_fifa.tm).to_dict()

df_fp["main_position"] = df_fp["main_position"].replace(positions_tm_in_fifa_dict)

df_fp.head()
# Out:
#    market_value_€        player_name                            long_name  \
# 0     112000000.0       Lionel Messi       Lionel Andrés Messi Cuccittini
# 1      60000000.0  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro
# 2     128000000.0             Neymar        Neymar da Silva Santos Junior
# 3     120000000.0    Kevin De Bruyne                      Kevin De Bruyne
# 4      80000000.0        Eden Hazard                          Eden Hazard
#
#    year_of_birth  player_age  height_cm  weight_kg nationality  \
# 0           1987          32        170         72   Argentina
# 1           1985          35        187         83    Portugal
# 2           1992          28        175         68      Brazil
# 3           1991          28        181         70     Belgium
# 4           1991          28        175         74     Belgium
#
#   geographical_continent              main_position all_positions  \
# 0          South America              Right Forward    RW, CF, ST
# 1                 Europe               Left Forward        ST, LW
# 2          South America               Left Forward       LW, CAM
# 3                 Europe  Centre Attacking Midfield       CAM, CM
# 4                 Europe               Left Forward        LW, CF
#
#                      club          league  divison  \
# 0            FC Barcelona          LaLiga        1
# 1          Juventus Turin         Serie A        1
# 2  FC Paris Saint-Germain         Ligue 1        1
# 3         Manchester City  Premier League        1
# 4             Real Madrid          LaLiga        1
#
#    national_team_current_or_past national_team_country  \
# 0                              1             Argentina
# 1                              1              Portugal
# 2                              1                Brazil
# 3                              1               Belgium
# 4                              1               Belgium
#
#    current_national_player  no_current_national_player  \
# 0                        1                           0
# 1                        1                           0
# 2                        1                           0
# 3                        1                           0
# 4                        1                           0
#
#    national_team_appearances  international_reputation  overall  potential  \
# 0                        138                         5       94         94
# 1                        164                         5       93         93
# 2                        102                         5       92         92
# 3                         74                         4       91         91
# 4                        106                         4       91         91
#
#   preferred_foot  weak_foot  skill_moves    work_rate  pace  shooting  \
# 0           Left          4            4   Medium/Low    87        92
# 1          Right          4            5     High/Low    90        93
# 2          Right          5            5  High/Medium    91        85
# 3          Right          5            4    High/High    76        86
# 4          Right          4            4  High/Medium    91        83
#
#    passing  dribbling  defending  physic  \
# 0       92         96         39      66
# 1       82         89         35      78
# 2       87         95         32      58
# 3       92         86         61      78
# 4       86         94         35      66
#
#                                        player_traits  attacking_crossing  \
# 0  Beat Offside Trap, Argues with Officials, Earl...                  88
# 1  Long Throw-in, Selfish, Argues with Officials,...                  84
# 2  Power Free-Kick, Injury Free, Selfish, Early C...                  87
# 3  Power Free-Kick, Avoids Using Weaker Foot, Div...                  93
# 4  Beat Offside Trap, Selfish, Finesse Shot, Spee...                  81
#
#    attacking_finishing  attacking_heading_accuracy  attacking_short_passing  \
# 0                   95                          70                       92
# 1                   94                          89                       83
# 2                   87                          62                       87
# 3                   82                          55                       92
# 4                   84                          61                       89
#
#    attacking_volleys  skill_dribbling  skill_curve  skill_fk_accuracy  \
# 0                 88               97           93                 94
# 1                 87               89           81                 76
# 2                 87               96           88                 87
# 3                 82               86           85                 83
# 4                 83               95           83                 79
#
#    skill_long_passing  skill_ball_control  movement_acceleration  \
# 0                  92                  96                     91
# 1                  77                  92                     89
# 2                  81                  95                     94
# 3                  91                  91                     77
# 4                  83                  94                     94
#
#    movement_sprint_speed  movement_agility  movement_reactions  \
# 0                     84                93                  95
# 1                     91                87                  96
# 2                     89                96                  92
# 3                     76                78                  91
# 4                     88                95                  90
#
#    movement_balance  power_shot_power  power_jumping  power_stamina  \
# 0                95                86             68             75
# 1                71                95             95             85
# 2                84                80             61             81
# 3                76                91             63             89
# 4                94                82             56             84
#
#    power_strength  power_long_shots  mentality_aggression  \
# 0              68                94                    48
# 1              78                93                    63
# 2              49                84                    51
# 3              74                90                    76
# 4              63                80                    54
#
#    mentality_interceptions  mentality_positioning  mentality_vision  \
# 0                       40                     94                94
# 1                       29                     95                82
# 2                       36                     87                90
# 3                       61                     88                94
# 4                       41                     87                89
#
#    mentality_penalties  mentality_composure  defending_marking  \
# 0                   75                   96                 33
# 1                   85                   95                 28
# 2                   90                   94                 27
# 3                   79                   91                 68
# 4                   88                   91                 34
#
#    defending_standing_tackle  defending_sliding_tackle  ls  st  rs  lw  lf  \
# 0                         37                        26  89  89  89  93  93
# 1                         32                        24  91  91  91  89  90
# 2                         26                        29  84  84  84  90  89
# 3                         58                        51  82  82  82  87  87
# 4                         27                        22  83  83  83  89  88
#
#    cf  rf  rw  lam  cam  ram  lm  lcm  cm  rcm  rm  lwb  ldm  cdm  rdm  rwb  \
# 0  93  93  93   93   93   93  92   87  87   87  92   68   66   66   66   68
# 1  90  90  89   88   88   88  88   81  81   81  88   65   61   61   61   65
# 2  89  89  90   90   90   90  89   82  82   82  89   66   61   61   61   66
# 3  87  87  87   88   88   88  88   87  87   87  88   77   77   77   77   77
# 4  88  88  89   89   89   89  89   83  83   83  89   66   63   63   63   66
#
#    lb  lcb  cb  rcb  rb
# 0  63   52  52   52  63
# 1  61   53  53   53  61
# 2  61   46  46   46  61
# 3  73   66  66   66  73
# 4  61   49  49   49  61

# %%
df_fp["all_positions"] = df_fp.all_positions.map(lambda x: [i.strip() for i in x.split(",")])
df_fp["positional_flexibility"] = df_fp["all_positions"].str.len()
df_fp["positional_flexibility"] = df_fp["positional_flexibility"].astype("object")
df_fp = df_fp.drop(["all_positions"],axis=1)
df_fp = movecol(df_fp, cols_to_move=["positional_flexibility"], ref_col="main_position", place="After")

df_fp.head(10)
# Out:
#    market_value_€        player_name                            long_name  \
# 0     112000000.0       Lionel Messi       Lionel Andrés Messi Cuccittini
# 1      60000000.0  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro
# 2     128000000.0             Neymar        Neymar da Silva Santos Junior
# 3     120000000.0    Kevin De Bruyne                      Kevin De Bruyne
# 4      80000000.0        Eden Hazard                          Eden Hazard
# 5      80000000.0    Virgil van Dijk                      Virgil van Dijk
# 6     120000000.0      Mohamed Salah                 Mohamed  Salah Ghaly
# 7      12000000.0        Luka Modric                          Luka Modrić
# 8      52000000.0      Sergio Agüero    Sergio Leonel Agüero del Castillo
# 9      80000000.0       N'Golo Kanté                         N'Golo Kanté
#
#    year_of_birth  player_age  height_cm  weight_kg  nationality  \
# 0           1987          32        170         72    Argentina
# 1           1985          35        187         83     Portugal
# 2           1992          28        175         68       Brazil
# 3           1991          28        181         70      Belgium
# 4           1991          28        175         74      Belgium
# 5           1991          28        193         92  Netherlands
# 6           1992          27        175         71        Egypt
# 7           1985          34        172         66      Croatia
# 8           1988          32        173         70    Argentina
# 9           1991          29        168         72       France
#
#   geographical_continent              main_position positional_flexibility  \
# 0          South America              Right Forward                      3
# 1                 Europe               Left Forward                      2
# 2          South America               Left Forward                      2
# 3                 Europe  Centre Attacking Midfield                      2
# 4                 Europe               Left Forward                      2
# 5                 Europe                Centre Back                      1
# 6                 Africa              Right Forward                      2
# 7                 Europe            Centre Midfield                      1
# 8          South America                    Striker                      1
# 9                 Europe            Centre Midfield                      2
#
#                      club          league  divison  \
# 0            FC Barcelona          LaLiga        1
# 1          Juventus Turin         Serie A        1
# 2  FC Paris Saint-Germain         Ligue 1        1
# 3         Manchester City  Premier League        1
# 4             Real Madrid          LaLiga        1
# 5            FC Liverpool  Premier League        1
# 6            FC Liverpool  Premier League        1
# 7             Real Madrid          LaLiga        1
# 8         Manchester City  Premier League        1
# 9              FC Chelsea  Premier League        1
#
#    national_team_current_or_past national_team_country  \
# 0                              1             Argentina
# 1                              1              Portugal
# 2                              1                Brazil
# 3                              1               Belgium
# 4                              1               Belgium
# 5                              1           Netherlands
# 6                              1                 Egypt
# 7                              1               Croatia
# 8                              1             Argentina
# 9                              1                France
#
#    current_national_player  no_current_national_player  \
# 0                        1                           0
# 1                        1                           0
# 2                        1                           0
# 3                        1                           0
# 4                        1                           0
# 5                        1                           0
# 6                        1                           0
# 7                        1                           0
# 8                        1                           0
# 9                        1                           0
#
#    national_team_appearances  international_reputation  overall  potential  \
# 0                        138                         5       94         94
# 1                        164                         5       93         93
# 2                        102                         5       92         92
# 3                         74                         4       91         91
# 4                        106                         4       91         91
# 5                         33                         3       90         91
# 6                         67                         3       90         90
# 7                        127                         4       90         90
# 8                         97                         4       89         89
# 9                         39                         3       89         90
#
#   preferred_foot  weak_foot  skill_moves      work_rate  pace  shooting  \
# 0           Left          4            4     Medium/Low    87        92
# 1          Right          4            5       High/Low    90        93
# 2          Right          5            5    High/Medium    91        85
# 3          Right          5            4      High/High    76        86
# 4          Right          4            4    High/Medium    91        83
# 5          Right          3            2  Medium/Medium    77        60
# 6           Left          3            4    High/Medium    93        86
# 7          Right          4            4      High/High    74        76
# 8          Right          4            4    High/Medium    80        90
# 9          Right          3            2    Medium/High    78        65
#
#    passing  dribbling  defending  physic  \
# 0       92         96         39      66
# 1       82         89         35      78
# 2       87         95         32      58
# 3       92         86         61      78
# 4       86         94         35      66
# 5       70         71         90      86
# 6       81         89         45      74
# 7       89         89         72      66
# 8       77         88         33      74
# 9       77         81         87      83
#
#                                        player_traits  attacking_crossing  \
# 0  Beat Offside Trap, Argues with Officials, Earl...                  88
# 1  Long Throw-in, Selfish, Argues with Officials,...                  84
# 2  Power Free-Kick, Injury Free, Selfish, Early C...                  87
# 3  Power Free-Kick, Avoids Using Weaker Foot, Div...                  93
# 4  Beat Offside Trap, Selfish, Finesse Shot, Spee...                  81
# 5  Diver, Avoids Using Weaker Foot, Leadership, L...                  53
# 6  Beat Offside Trap, Argues with Officials, Earl...                  79
# 7  Argues with Officials, Finesse Shot, Speed Dri...                  86
# 8        Avoids Using Weaker Foot, Outside Foot Shot                  70
# 9                                              Diver                  68
#
#    attacking_finishing  attacking_heading_accuracy  attacking_short_passing  \
# 0                   95                          70                       92
# 1                   94                          89                       83
# 2                   87                          62                       87
# 3                   82                          55                       92
# 4                   84                          61                       89
# 5                   52                          86                       78
# 6                   90                          59                       84
# 7                   72                          55                       92
# 8                   93                          78                       83
# 9                   65                          54                       86
#
#    attacking_volleys  skill_dribbling  skill_curve  skill_fk_accuracy  \
# 0                 88               97           93                 94
# 1                 87               89           81                 76
# 2                 87               96           88                 87
# 3                 82               86           85                 83
# 4                 83               95           83                 79
# 5                 45               70           60                 70
# 6                 79               89           83                 69
# 7                 76               87           85                 78
# 8                 85               88           83                 73
# 9                 56               79           49                 49
#
#    skill_long_passing  skill_ball_control  movement_acceleration  \
# 0                  92                  96                     91
# 1                  77                  92                     89
# 2                  81                  95                     94
# 3                  91                  91                     77
# 4                  83                  94                     94
# 5                  81                  76                     74
# 6                  75                  89                     94
# 7                  88                  92                     77
# 8                  64                  89                     82
# 9                  81                  80                     79
#
#    movement_sprint_speed  movement_agility  movement_reactions  \
# 0                     84                93                  95
# 1                     91                87                  96
# 2                     89                96                  92
# 3                     76                78                  91
# 4                     88                95                  90
# 5                     79                61                  88
# 6                     92                91                  92
# 7                     71                92                  89
# 8                     78                84                  92
# 9                     77                82                  93
#
#    movement_balance  power_shot_power  power_jumping  power_stamina  \
# 0                95                86             68             75
# 1                71                95             95             85
# 2                84                80             61             81
# 3                76                91             63             89
# 4                94                82             56             84
# 5                53                81             90             75
# 6                88                80             69             85
# 7                93                79             68             85
# 8                91                89             81             79
# 9                92                71             77             97
#
#    power_strength  power_long_shots  mentality_aggression  \
# 0              68                94                    48
# 1              78                93                    63
# 2              49                84                    51
# 3              74                90                    76
# 4              63                80                    54
# 5              92                64                    82
# 6              73                84                    63
# 7              58                82                    62
# 8              74                84                    65
# 9              73                63                    90
#
#    mentality_interceptions  mentality_positioning  mentality_vision  \
# 0                       40                     94                94
# 1                       29                     95                82
# 2                       36                     87                90
# 3                       61                     88                94
# 4                       41                     87                89
# 5                       89                     47                65
# 6                       55                     92                84
# 7                       82                     79                91
# 8                       24                     93                83
# 9                       92                     72                79
#
#    mentality_penalties  mentality_composure  defending_marking  \
# 0                   75                   96                 33
# 1                   85                   95                 28
# 2                   90                   94                 27
# 3                   79                   91                 68
# 4                   88                   91                 34
# 5                   62                   89                 91
# 6                   77                   91                 38
# 7                   82                   92                 68
# 8                   83                   90                 30
# 9                   54                   85                 90
#
#    defending_standing_tackle  defending_sliding_tackle  ls  st  rs  lw  lf  \
# 0                         37                        26  89  89  89  93  93
# 1                         32                        24  91  91  91  89  90
# 2                         26                        29  84  84  84  90  89
# 3                         58                        51  82  82  82  87  87
# 4                         27                        22  83  83  83  89  88
# 5                         92                        85  69  69  69  67  69
# 6                         43                        41  84  84  84  88  88
# 7                         76                        71  77  77  77  84  83
# 8                         29                        24  87  87  87  85  87
# 9                         91                        85  72  72  72  77  76
#
#    cf  rf  rw  lam  cam  ram  lm  lcm  cm  rcm  rm  lwb  ldm  cdm  rdm  rwb  \
# 0  93  93  93   93   93   93  92   87  87   87  92   68   66   66   66   68
# 1  90  90  89   88   88   88  88   81  81   81  88   65   61   61   61   65
# 2  89  89  90   90   90   90  89   82  82   82  89   66   61   61   61   66
# 3  87  87  87   88   88   88  88   87  87   87  88   77   77   77   77   77
# 4  88  88  89   89   89   89  89   83  83   83  89   66   63   63   63   66
# 5  69  69  67   69   69   69  69   74  74   74  69   79   83   83   83   79
# 6  88  88  88   87   87   87  87   81  81   81  87   70   67   67   67   70
# 7  83  83  84   86   86   86  85   87  87   87  85   81   81   81   81   81
# 8  87  87  85   85   85   85  83   77  77   77  83   60   58   58   58   60
# 9  76  76  77   78   78   78  79   82  82   82  79   85   87   87   87   85
#
#    lb  lcb  cb  rcb  rb
# 0  63   52  52   52  63
# 1  61   53  53   53  61
# 2  61   46  46   46  61
# 3  73   66  66   66  73
# 4  61   49  49   49  61
# 5  81   87  87   87  81
# 6  66   57  57   57  66
# 7  79   72  72   72  79
# 8  56   50  50   50  56
# 9  84   83  83   83  84

# %%
# flexibility 2 --> find max and count how often / on how many positions
df_fp["ID"] = df_fp.index
df_fp["ID"] = df_fp["ID"].astype("object")
df_fp_flex = df_fp[["ID","player_name","ls","st","rs","lw","lf","cf","rf","rw","lam","cam","ram","lm","lcm","cm","rcm","rm","lwb","ldm","cdm","rdm","rwb","lb","lcb","cb","rcb","rb"]]
df_fp_flex["max_pos_value"] = df_fp_flex.max(axis=1)
df_fp_flex.head()
# Out:
# C:\Users\Fabian\Anaconda3\envs\nf\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#   ID        player_name  ls  st  rs  lw  lf  cf  rf  rw  lam  cam  ram  lm  \
# 0  0       Lionel Messi  89  89  89  93  93  93  93  93   93   93   93  92
# 1  1  Cristiano Ronaldo  91  91  91  89  90  90  90  89   88   88   88  88
# 2  2             Neymar  84  84  84  90  89  89  89  90   90   90   90  89
# 3  3    Kevin De Bruyne  82  82  82  87  87  87  87  87   88   88   88  88
# 4  4        Eden Hazard  83  83  83  89  88  88  88  89   89   89   89  89
#
#    lcm  cm  rcm  rm  lwb  ldm  cdm  rdm  rwb  lb  lcb  cb  rcb  rb  \
# 0   87  87   87  92   68   66   66   66   68  63   52  52   52  63
# 1   81  81   81  88   65   61   61   61   65  61   53  53   53  61
# 2   82  82   82  89   66   61   61   61   66  61   46  46   46  61
# 3   87  87   87  88   77   77   77   77   77  73   66  66   66  73
# 4   83  83   83  89   66   63   63   63   66  61   49  49   49  61
#
#    max_pos_value
# 0             93
# 1             91
# 2             90
# 3             88
# 4             89

# %%
for i in df_fp_flex.columns:
    df_fp_flex[f"{i}"] = df_fp_flex[f"{i}"].astype("object")
print(df_fp_flex.dtypes)
df_fp_flex.head()
# Out:
# C:\Users\Fabian\Anaconda3\envs\nf\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ID               object
# player_name      object
# ls               object
# st               object
# rs               object
# lw               object
# lf               object
# cf               object
# rf               object
# rw               object
# lam              object
# cam              object
# ram              object
# lm               object
# lcm              object
# cm               object
# rcm              object
# rm               object
# lwb              object
# ldm              object
# cdm              object
# rdm              object
# rwb              object
# lb               object
# lcb              object
# cb               object
# rcb              object
# rb               object
# max_pos_value    object
# dtype: object
#   ID        player_name  ls  st  rs  lw  lf  cf  rf  rw lam cam ram  lm lcm  \
# 0  0       Lionel Messi  89  89  89  93  93  93  93  93  93  93  93  92  87
# 1  1  Cristiano Ronaldo  91  91  91  89  90  90  90  89  88  88  88  88  81
# 2  2             Neymar  84  84  84  90  89  89  89  90  90  90  90  89  82
# 3  3    Kevin De Bruyne  82  82  82  87  87  87  87  87  88  88  88  88  87
# 4  4        Eden Hazard  83  83  83  89  88  88  88  89  89  89  89  89  83
#
#    cm rcm  rm lwb ldm cdm rdm rwb  lb lcb  cb rcb  rb max_pos_value
# 0  87  87  92  68  66  66  66  68  63  52  52  52  63            93
# 1  81  81  88  65  61  61  61  65  61  53  53  53  61            91
# 2  82  82  89  66  61  61  61  66  61  46  46  46  61            90
# 3  87  87  88  77  77  77  77  77  73  66  66  66  73            88
# 4  83  83  89  66  63  63  63  66  61  49  49  49  61            89

# %% [markdown]
# ## 3 - Average over positional values

# %% [markdown]
# ## 4 - Workrate, Int. Reputation, Skill Moves

# %% [markdown]
# ## 5 - Player traits

# %% [markdown]
# #### Work to do next notebook
# - truncate dataframe
# - do second EDA, after dataframe has been truncated and features have been engineered
# - especially have a look at national team appearances
# - check for correlation among features!!!
# - clustering & other unsupervised learning methods???
#
# #### further work
# - build preprocessing pipeline for numerical and categorical vars separately
